# %% [markdown]
# # Home Work One - ML Zoomcamp 2026
#
# Hi, I'm Norman! This is my submission for Home Work 1 for ML ZoomCamp 2026.
#
# Let’s connect on [LinkedIn](https://www.linkedin.com/in/anormanangel/) and [Twitter](https://x.com/anormanangel) to keep learning together.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/DataTalksClub/machine-learning-zoomcamp/main/cohorts/2026/data/car_fuel_efficiency_2026.csv')

df.head()
# Out:
#    model_year  origin fuel_type         drivetrain  num_doors  \
# 0        2006  Europe  Gasoline  Front-wheel drive          4
# 1        2008  Europe    Diesel  Front-wheel drive          4
# 2        1996    Asia  Gasoline  Front-wheel drive          5
# 3        1989  Europe  Gasoline  Front-wheel drive          4
# 4        1994     USA    Diesel  Front-wheel drive          3
#
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                 2180              6       243.0            3870
# 1                 2390              6       272.0            4210
# 2                 2320              6       267.0            4240
# 3                 2130              6       258.0            4490
# 4                 2580              7       304.0            4510
#
#    acceleration  fuel_efficiency_mpg
# 0           NaN                 31.9
# 1           NaN                 31.3
# 2          17.3                 27.5
# 3          18.7                 28.5
# 4          17.5                 31.0

# %% [markdown]
# ### Q1. Pandas version: What version of Pandas did you install?

# %%
pd.__version__
# Out:
# '3.0.1'

# %% [markdown]
# ### Q2. Records count: How many records are in the dataset?

# %%
df.shape
# Out:
# (10000, 11)

# %% [markdown]
# ### Q3. Fuel types: How many fuel types are presented in the dataset?

# %%
df['fuel_type'].nunique()
# Out:
# 3

# %% [markdown]
# ### Q4. Missing values: How many columns in the dataset have missing values?

# %%
df.isnull().sum()
# Out:
# model_year               0
# origin                   0
# fuel_type                0
# drivetrain               0
# num_doors                0
# engine_displacement      0
# num_cylinders            0
# horsepower             877
# vehicle_weight           0
# acceleration           264
# fuel_efficiency_mpg      0
# dtype: int64

# %%
(df.isnull().sum() > 0).sum()
# Out:
# 2

# %% [markdown]
# Q5. Max fuel efficiency: What's the maximum fuel efficiency of cars from Asia?

# %%
df[df['origin'] == 'Asia']['fuel_efficiency_mpg'].max()
# Out:
# 41.2

# %% [markdown]
# ### Q6. Median value of horsepower
# - Find the median value of the horsepower column in the dataset.
# - Next, calculate the most frequent value of the same horsepower column.
# - Use the fillna method to fill the missing values in the horsepower column with the most frequent value from the previous step.
# #### Now, calculate the median value of horsepower once again.
# - Has it changed?
#
# -Yes, it increased
# - Yes, it decreased
# - No

# %%
# Median horse power: Most Frequent

df['horsepower'].median()
# Out:
# 254.0

# %%
# Most Frequent horse power: Mode

df['horsepower'].mode()
# Out:
# 0    252.0
# Name: horsepower, dtype: float64

# %%
# Filling missin values in horsepower column with mode

df['horsepower'] = df['horsepower'].fillna(df['horsepower'].mode()[0])

# %%
# Calculate the median again

df['horsepower'].median()
# Out:
# 252.0

# %% [markdown]
# ### 07. Sum of Weights

# %%
# Select all cars from Asia

df_asia = df[df['origin'] == 'Asia']

# %%
# Select vehicle_weight and model_year

X = df_asia[['vehicle_weight', 'model_year']]

# %%
# Sellect the first 7 rows

X = X.head(7)

# %%
# Get the underlying NumPy array. Let's call it X

X
# Out:
#       vehicle_weight  model_year
# 2               4240        1996
# 6               4310        1992
# 8               4230        1997
# 10              4420        1978
# 15              3950        2007
# ...              ...         ...
# 9984            4610        2011
# 9987            4530        2004
# 9990            3630        1975
# 9994            4610        1993
# 9996            4370        1993
#
# [2994 rows x 2 columns]

# %%
# Compute matrix-matrix multiplication between the transpose of X and X. To get the transpose, use X.T. Let's call the result XTX.

X = df[df['origin'] == 'Asia'][['vehicle_weight', 'model_year']].head(7).values

# %%
XTX = X.T @ X

XTX
# Out:
# array([[131950500,  60750580],
#        [ 60750580,  28041424]])

# %%
# Invert XTX

XTX_inv = np.linalg.inv(XTX)

# %%
# Create an array y with values [1100, 1300, 800, 900, 1000, 1100, 1200]

y = np.array([1100, 1300, 800, 900, 1000, 1100, 1200])

# %%
# Multiply the inverse of XTX with the transpose of X, and then multiply the result by y. Call the result w.

w = XTX_inv @ X.T @ y

# %%
# Sum of elements w

w.sum()
# Out:
# 0.3691969690492758
